# %% [markdown]
# # Mini Projeto 1
#
# ## Nome: Carlos Felipe Mothé Zarour
# ## Nome: Allan dos Santos Vilela
# ## Nome: Enzo Hernandes Silvério

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/renatapink/DSdegree/master/Modulo2/Mini_projeto2/investidores.csv')

# %%
df
# Out:
#               id                                     Nome  Sexo  idade  \
# 0      id0000002          Sebastião Castelo Branco Júnior  Masc     33
# 1      id0000003                Romildo Fábio de Carvalho  Masc     40
# 2      id0000004                Lana Albina de Lemos Mumy   Fem     51
# 3      id0000005         Rose Elisângela Vyrnium de Moura   Fem     39
# 4      id0000006  Osório Mário de Parreira Sassoer Otremo  Masc     60
# ...          ...                                      ...   ...    ...
# 28056  id0038746                           Paula de Lemes   Fem     23
# 28057  id0038749                         Martin Mike Ocai  Masc     46
# 28058  id0038750          Beatriz Maísa de Miranda Milani   Fem     20
# 28059  id0038752            Severino Edson de Viana Loase  Masc     43
# 28060  id0038753                               Kim Mooshi  Masc     48
#
#                             Email                                    Job  \
# 0          barnesandrea@yahoo.com                   Biochemist, clinical
# 1         walkermichael@yahoo.com  Development worker, international aid
# 2          cobbangela@hotmail.com              Estate manager/land agent
# 3         crawfordcraig@yahoo.com    Chartered public finance accountant
# 4       ramirezjennifer@yahoo.com                              Press sub
# ...                           ...                                    ...
# 28056  reynoldsjennifer@gmail.com           Trade union research officer
# 28057      walshshelley@yahoo.com                          Ranger/warden
# 28058            mark47@gmail.com             Further education lecturer
# 28059           cindy11@yahoo.com               Arts development officer
# 28060     mcdonaldmario@gmail.com                     Production manager
#
#       Estado     Renda       Perfil  Ativo01  ...  Ativo03   Ativo04  Ativo05  \
# 0         DF     21.96     Moderado   842.12  ...  3336.07  14052.91  5624.22
# 1         DF  62497.64  Conservador   818.81  ...  3396.64  14052.91  5033.83
# 2         DF  99878.74    Agressivo  1095.92  ...  3723.10  14052.91  5933.91
# 3         MS    188.01  Conservador  1505.16  ...  3462.67  30841.35  6044.86
# 4         MS    375.93  Conservador   858.43  ...  3097.11  13431.14  4409.81
# ...      ...       ...          ...      ...  ...      ...       ...      ...
# 28056     RJ    487.06  Conservador  1094.12  ...  3376.45  19323.07  6605.23
# 28057     MT   7172.41  Conservador   988.55  ...  3097.11  17341.08  4866.52
# 28058     RS   4993.49     Moderado  1001.01  ...  3097.11   8454.99  5200.28
# 28059     PR     32.41    Agressivo  1163.90  ...  3746.62  14052.91  6733.79
# 28060     RJ    914.52  Conservador  1095.92  ...  2861.32  14052.91  4921.77
#
#         Ativo06  Ativo07     Total      Reserva  Invest_curto_prazo  \
# 0      2669.980   504.17  18622.65      22.6188              26.352
# 1      2229.450   523.12  17518.37   64372.5692          124995.280
# 2      2270.165   486.05  15401.75  102875.1022          199757.480
# 3      2198.890   512.98  50981.21     193.6503             225.612
# 4      2270.165   492.03  24820.16     387.2079             451.116
# ...         ...      ...       ...          ...                 ...
# 28056  2164.760   510.60  38693.13     501.6718             633.178
# 28057  2049.560   498.69  30488.65    7387.5823            7172.410
# 28058  2191.780   489.76  17699.09    5143.2947            4993.490
# 28059  2338.430   504.32  19398.69      33.3823              32.410
# 28060  2024.000   500.65  15840.09     941.9556             914.520
#
#        Invest_medio_prazo  Invest_longo_prazo
# 0                  35.136              39.528
# 1               99996.224           99996.224
# 2              199757.480          299636.220
# 3                 225.612             282.015
# 4                 676.674             563.895
# ...                   ...                 ...
# 28056             681.884            2922.360
# 28057           10041.374           10758.615
# 28058            8988.282            6990.886
# 28059              38.892              38.892
# 28060            1097.424            1554.684
#
# [28061 rows x 21 columns]

# %% [markdown]
# ## 1) Faça um gráfico para ver a distribuição da idade dos investidores
# ### (histograma)

# %%
age = df['idade']
plt.hist(age, density=False)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2) Faça um gráfico de pizza para ver a distribuição dos perfis dos investidores
# ### Coloque o valor das porcentagens e a legenda dica: usar value_counts()

# %%
df['Perfil'].value_counts().plot.pie(subplots = True, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## 3) Faça um gráfico de barras verticais da quantidade de investidores por estado
# ### dica: usar value_counts() ou groupby

# %%
df.groupby(['Estado'])[['id']].count().plot.bar(rot=0 , figsize=(16,10))
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ## 4) Faça um gráfico de barras horizontais da soma dos ativos01 a ativos07
# ### dica: pode usar df[['Ativo01','Ativo02','Ativo03','Ativo04','Ativo05','Ativo06','Ativo07']].sum()

# %%
df1 = df[['Ativo01', 'Ativo02', 'Ativo03', 'Ativo04',
       'Ativo05', 'Ativo06', 'Ativo07']].sum()
df1.plot.barh()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## 5) Faça um gráfico para ver a distribuição dos valores do Ativo07 usando boxplot
# ### Na mesma figura compare a distribuição do Ativo07 em cada estado

# %%
fig, ax = plt.subplots(figsize=(18, 10))
sns.boxplot(x='Estado', y='Ativo07',  data=df )
plt.grid(which='minor')
plt.show()

# %% [markdown]
# ## 6) Faça um gráfico de dispersão dos Ativo04 e Ativo07
# ### Na mesma figura use cores para identificar o perfil

# %%
fig, ax = plt.subplots(figsize=(22, 10))
sns.scatterplot(data=df, x='Ativo04', y='Ativo07', hue='Perfil' )
plt.grid()
sns.set()

# %%
from sklearn.cluster import KMeans
X = df[['Ativo04', 'Ativo07']]
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)

df['Perfil'] = kmeans.labels_

sns.scatterplot(data=df, x='Ativo04', y='Ativo07', hue='Perfil')
# Out:
# <AxesSubplot:xlabel='Ativo04', ylabel='Ativo07'>

# %% [markdown]
# ## 7) Faça um mapa de calor com a correlação entre Renda, Reserva, Investimentos a curto, médio e longo prazo
# ### Coloque argumentos de anotação e use o cmap = 'plasma'
# ### dica: Use essa correlação - df[['Renda','Invest_curto_prazo','Invest_medio_prazo','Invest_longo_prazo', 'Reserva']].corr()

# %%
df[['Renda','Invest_curto_prazo','Invest_medio_prazo','Invest_longo_prazo', 'Reserva']].corr()

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(data=df[['Renda','Invest_curto_prazo','Invest_medio_prazo','Invest_longo_prazo', 'Reserva']].corr(), annot=True, cmap='plasma')
plt.title('Mapa de Calor: Correlações')
sns.set()

# %% [markdown]
# ## 8) No gráfico de linhas abaixo, acrescente:
# ### Título: Total de investimento em cada ativo
# ### Mude o tamanho da figura
# ### Nome nos eixos
# ### Linha vermelha horizontal em 50000000
# ### Grade
# ### Rotacione os ticks do eixo x em 45º
# ### Mude os ticks do eixo y para azul
# ### Legenda no centro da figura

# %%
df1 = df.groupby('Estado')[['Ativo01', 'Ativo02', 'Ativo03', 'Ativo04', 'Ativo05', 'Ativo06', 'Ativo07']].sum()
df1.plot(figsize = (16,10))
plt.title('Total de investimento em cada ativo')
plt.xticks(rotation=45, color='gray')
plt.yticks(color = 'blue')
plt.xlabel('Estados', color='red')
plt.ylabel('Valor', color='red')
plt.legend(loc= 'center')
plt.axhline(50000000, color='red')
plt.ylim(0, 86000000)
plt.xlim()
plt.show()

# %%
from wordcloud import WordCloud

# %%
text = ','.join(df['Job'])

wordcloud = WordCloud(width=800, height=800, margin=0).generate(text)
plt.figure(figsize=(15, 12))
plt.imshow(wordcloud, interpolation='nearest')
plt.axis("off")
plt.margins(x=0, y=0)

# %%
from sklearn.cluster import KMeans

X = df[['Ativo01', 'Ativo02', 'Ativo03', 'Ativo04', 'Ativo05', 'Ativo06', 'Ativo07']]
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)

df['cluster'] = kmeans.labels_

sns.scatterplot(data=df, x='Ativo04', y='Ativo07', hue='cluster')
# Out:
# <AxesSubplot:xlabel='Ativo04', ylabel='Ativo07'>

# %%
import mplfinance as mpf

ibov = pd.read_csv('https://raw.githubusercontent.com/renatapink/DSdegree/master/Modulo2/Aula05/BVSP2.csv')

ibov['Date'] = pd.to_datetime(ibov['Date']) 
ibov = ibov.set_index('Date') 
mpf.plot(ibov[-50:], type='candle', style='starsandstripes', volume=True)
